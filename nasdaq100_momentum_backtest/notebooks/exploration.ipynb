# %% [markdown]
# # Exploration
#
# Quick interactive exploration of the backtest outputs.

# %%
import os, sys
import pandas as pd

sys.path.insert(0, os.path.abspath('..'))

selections = pd.read_csv('../outputs/monthly_selections.csv', parse_dates=['rebalance_date', 'exit_date'])
returns = pd.read_csv('../outputs/portfolio_returns.csv', parse_dates=['rebalance_date', 'next_rebalance_date'])
summary = pd.read_csv('../outputs/summary_stats.csv', index_col=0)
summary

# %%
selections['ticker'].value_counts().head(20)

# %%
returns[['rebalance_date', 'portfolio_return_net', 'qqq_return', 'excess_return', 'portfolio_value', 'qqq_value']].tail(12)
